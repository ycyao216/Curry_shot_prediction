# %%
import lightgbm as lgb
import numpy as np
import optuna
import sklearn

# %%
train = np.loadtxt('train4.csv', delimiter=',', skiprows=1)
valid = np.loadtxt('valid4.csv', delimiter=',', skiprows=1)
test = np.loadtxt('test4.csv', delimiter=',', skiprows=1)

# %%
n_features = train.shape[1] - 1
    
X_train = train[:, :n_features]
X_valid = valid[:, :n_features]
X_test = test[:, :n_features]
    
y_train = train[:, n_features:]
y_valid = valid[:, n_features:]
y_test = test[:, n_features:]

# %%
eval_res = {}

def objective(trial):
    dtrain = lgb.Dataset(X_train, label=y_train)
    dvalid = lgb.Dataset(X_valid, label=y_valid)

    param = {
        "objective": "binary",
        "metric": "val_loss",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        'seed': 42
    }

    gbm = lgb.train(param, dtrain, valid_sets=dvalid)
    preds = gbm.predict(X_test)
    pred_labels = np.rint(preds)
    accuracy = sklearn.metrics.accuracy_score(y_test, pred_labels)
    return accuracy

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
# Out:
# [I 2021-11-22 14:52:55,088] A new study created in memory with name: no-name-03fbea7f-8013-455c-b851-773f879a7922
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,122] Trial 0 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 1.3595957072619465e-07, 'lambda_l2': 0.24058568451707682, 'num_leaves': 107, 'feature_fraction': 0.9178607734556815, 'bagging_fraction': 0.7292547642561444, 'bagging_freq': 2, 'min_child_samples': 98}. Best is trial 0 with value: 0.5979381443298969.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,154] Trial 1 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 0.008892655711130454, 'lambda_l2': 6.187897447071488e-07, 'num_leaves': 154, 'feature_fraction': 0.7998898172498368, 'bagging_fraction': 0.7314733657864022, 'bagging_freq': 7, 'min_child_samples': 56}. Best is trial 0 with value: 0.5979381443298969.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,180] Trial 2 finished with value: 0.5773195876288659 and parameters: {'lambda_l1': 0.010636164153550643, 'lambda_l2': 0.05187671912958834, 'num_leaves': 182, 'feature_fraction': 0.5367721176262156, 'bagging_fraction': 0.47273567347608586, 'bagging_freq': 6, 'min_child_samples': 74}. Best is trial 0 with value: 0.5979381443298969.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,207] Trial 3 finished with value: 0.5773195876288659 and parameters: {'lambda_l1': 9.354241834330168e-07, 'lambda_l2': 5.1836933654773374e-08, 'num_leaves': 134, 'feature_fraction': 0.5895034823109777, 'bagging_fraction': 0.40432022131207845, 'bagging_freq': 7, 'min_child_samples': 46}. Best is trial 0 with value: 0.5979381443298969.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,266] Trial 4 finished with value: 0.6907216494845361 and parameters: {'lambda_l1': 1.7223208762016493e-06, 'lambda_l2': 0.0003938813884026949, 'num_leaves': 23, 'feature_fraction': 0.8164434077638283, 'bagging_fraction': 0.9379967492292598, 'bagging_freq': 6, 'min_child_samples': 9}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,334] Trial 5 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 6.667669896018759e-05, 'lambda_l2': 2.4478817208930755e-07, 'num_leaves': 118, 'feature_fraction': 0.4114446414144349, 'bagging_fraction': 0.8972406434992921, 'bagging_freq': 5, 'min_child_samples': 21}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,363] Trial 6 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 2.490169157524803e-08, 'lambda_l2': 9.691093320968082e-06, 'num_leaves': 211, 'feature_fraction': 0.6793030451634117, 'bagging_fraction': 0.8774336468186762, 'bagging_freq': 1, 'min_child_samples': 100}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,397] Trial 7 finished with value: 0.5773195876288659 and parameters: {'lambda_l1': 1.7100682780192072e-08, 'lambda_l2': 0.0005491536045719838, 'num_leaves': 139, 'feature_fraction': 0.6837101861452035, 'bagging_fraction': 0.7322541906555836, 'bagging_freq': 7, 'min_child_samples': 51}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,422] Trial 8 finished with value: 0.5670103092783505 and parameters: {'lambda_l1': 1.9026175687010718, 'lambda_l2': 0.03144605793276471, 'num_leaves': 52, 'feature_fraction': 0.5625541720741104, 'bagging_fraction': 0.6164723035843239, 'bagging_freq': 1, 'min_child_samples': 92}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,448] Trial 9 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 0.0050808997277346285, 'lambda_l2': 3.000638201570926e-07, 'num_leaves': 98, 'feature_fraction': 0.530368201943034, 'bagging_fraction': 0.47623725308217024, 'bagging_freq': 3, 'min_child_samples': 65}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,499] Trial 10 finished with value: 0.5463917525773195 and parameters: {'lambda_l1': 9.313322624421741e-06, 'lambda_l2': 0.0009014115848874654, 'num_leaves': 13, 'feature_fraction': 0.9418788571764183, 'bagging_fraction': 0.9997881854117184, 'bagging_freq': 4, 'min_child_samples': 7}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,614] Trial 11 finished with value: 0.5773195876288659 and parameters: {'lambda_l1': 4.311675163803001e-05, 'lambda_l2': 2.3593754668408632e-05, 'num_leaves': 250, 'feature_fraction': 0.42690239176042316, 'bagging_fraction': 0.918372511289344, 'bagging_freq': 5, 'min_child_samples': 12}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,672] Trial 12 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 0.0002754503456308661, 'lambda_l2': 1.3684924629908759e-05, 'num_leaves': 62, 'feature_fraction': 0.8141882317546754, 'bagging_fraction': 0.8656252787325336, 'bagging_freq': 5, 'min_child_samples': 28}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,708] Trial 13 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 1.963339253214769e-06, 'lambda_l2': 1.505926106080409e-08, 'num_leaves': 5, 'feature_fraction': 0.8068055832874403, 'bagging_fraction': 0.9987610496331549, 'bagging_freq': 5, 'min_child_samples': 28}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,771] Trial 14 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 0.00016401687686211103, 'lambda_l2': 0.0048689533700996225, 'num_leaves': 68, 'feature_fraction': 0.4078083864613608, 'bagging_fraction': 0.8166514192438897, 'bagging_freq': 4, 'min_child_samples': 22}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,816] Trial 15 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 0.3320230239237088, 'lambda_l2': 7.98288487722226e-05, 'num_leaves': 35, 'feature_fraction': 0.8863771629171865, 'bagging_fraction': 0.6245426604970971, 'bagging_freq': 6, 'min_child_samples': 38}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:55,898] Trial 16 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 8.62167444318173e-06, 'lambda_l2': 1.3182763010249702e-06, 'num_leaves': 90, 'feature_fraction': 0.7357038468447434, 'bagging_fraction': 0.8066036321058146, 'bagging_freq': 6, 'min_child_samples': 16}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,013] Trial 17 finished with value: 0.5876288659793815 and parameters: {'lambda_l1': 6.171225435283554e-07, 'lambda_l2': 6.11471928633591, 'num_leaves': 80, 'feature_fraction': 0.997372901760621, 'bagging_fraction': 0.8150908994231731, 'bagging_freq': 6, 'min_child_samples': 7}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,070] Trial 18 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 0.001085601955427975, 'lambda_l2': 0.0027221885158619785, 'num_leaves': 172, 'feature_fraction': 0.641071777715158, 'bagging_fraction': 0.9287296924383865, 'bagging_freq': 3, 'min_child_samples': 36}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,155] Trial 19 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 7.352544486596637e-06, 'lambda_l2': 2.4339790357925355e-06, 'num_leaves': 39, 'feature_fraction': 0.7540000509176299, 'bagging_fraction': 0.8238767368087561, 'bagging_freq': 6, 'min_child_samples': 17}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,320] Trial 20 finished with value: 0.5567010309278351 and parameters: {'lambda_l1': 1.4520220117263987e-07, 'lambda_l2': 0.00014106348642085466, 'num_leaves': 88, 'feature_fraction': 0.7358437571381518, 'bagging_fraction': 0.6017938537297511, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,402] Trial 21 finished with value: 0.6597938144329897 and parameters: {'lambda_l1': 2.9013911259688843e-05, 'lambda_l2': 1.7405195313738977e-07, 'num_leaves': 100, 'feature_fraction': 0.8629453275952098, 'bagging_fraction': 0.9236178814067304, 'bagging_freq': 5, 'min_child_samples': 20}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,463] Trial 22 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 1.3002184078542375e-05, 'lambda_l2': 2.2770827928037987e-06, 'num_leaves': 27, 'feature_fraction': 0.8520229666202502, 'bagging_fraction': 0.9559608004316635, 'bagging_freq': 6, 'min_child_samples': 31}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,544] Trial 23 finished with value: 0.5670103092783505 and parameters: {'lambda_l1': 2.361926184850541e-06, 'lambda_l2': 5.7473333501123066e-08, 'num_leaves': 79, 'feature_fraction': 0.7538103642711758, 'bagging_fraction': 0.7755750970352259, 'bagging_freq': 5, 'min_child_samples': 16}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,615] Trial 24 finished with value: 0.5876288659793815 and parameters: {'lambda_l1': 7.808653708878947e-05, 'lambda_l2': 2.3435123797269507e-07, 'num_leaves': 117, 'feature_fraction': 0.8634931567423099, 'bagging_fraction': 0.8949528963881538, 'bagging_freq': 4, 'min_child_samples': 23}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,669] Trial 25 finished with value: 0.5876288659793815 and parameters: {'lambda_l1': 0.0013517813930214596, 'lambda_l2': 2.5891254672863113e-08, 'num_leaves': 120, 'feature_fraction': 0.9382594333310734, 'bagging_fraction': 0.9529442282111364, 'bagging_freq': 5, 'min_child_samples': 41}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,758] Trial 26 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 3.472623318906797e-05, 'lambda_l2': 1.7810863997034761e-07, 'num_leaves': 155, 'feature_fraction': 0.46372532090466395, 'bagging_fraction': 0.8597775972039645, 'bagging_freq': 3, 'min_child_samples': 19}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,851] Trial 27 finished with value: 0.5876288659793815 and parameters: {'lambda_l1': 1.4671766628680825e-07, 'lambda_l2': 4.9309629965753796e-05, 'num_leaves': 201, 'feature_fraction': 0.4709672176441577, 'bagging_fraction': 0.6727726087820244, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,914] Trial 28 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 0.10588695816747731, 'lambda_l2': 4.4717130431462494e-06, 'num_leaves': 56, 'feature_fraction': 0.6284105962137053, 'bagging_fraction': 0.9629554906316986, 'bagging_freq': 4, 'min_child_samples': 32}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:56,955] Trial 29 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 0.0008160618867581681, 'lambda_l2': 0.0002509502063215981, 'num_leaves': 170, 'feature_fraction': 0.9782786331144003, 'bagging_fraction': 0.856836853953228, 'bagging_freq': 2, 'min_child_samples': 76}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,016] Trial 30 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 4.278249683486739e-07, 'lambda_l2': 1.4514264495832485, 'num_leaves': 147, 'feature_fraction': 0.8996458229146448, 'bagging_fraction': 0.7507662399959377, 'bagging_freq': 2, 'min_child_samples': 25}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,095] Trial 31 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 3.7338676685691273e-05, 'lambda_l2': 1.591859255730859e-07, 'num_leaves': 106, 'feature_fraction': 0.4811707622386017, 'bagging_fraction': 0.904242881540846, 'bagging_freq': 4, 'min_child_samples': 20}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,206] Trial 32 finished with value: 0.5773195876288659 and parameters: {'lambda_l1': 4.3867644627206586e-05, 'lambda_l2': 4.3895913724978774e-07, 'num_leaves': 158, 'feature_fraction': 0.4766851107930496, 'bagging_fraction': 0.8508889040794083, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,299] Trial 33 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 4.132749197194013e-06, 'lambda_l2': 9.191640375537402e-07, 'num_leaves': 102, 'feature_fraction': 0.8331116850338545, 'bagging_fraction': 0.774602513694745, 'bagging_freq': 6, 'min_child_samples': 13}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,479] Trial 34 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 1.6314436673606796e-05, 'lambda_l2': 7.453147823150492e-08, 'num_leaves': 195, 'feature_fraction': 0.771645699342118, 'bagging_fraction': 0.6829925563117817, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,533] Trial 35 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 0.00016715152421042196, 'lambda_l2': 1.3560976144551907e-08, 'num_leaves': 126, 'feature_fraction': 0.4555954448507668, 'bagging_fraction': 0.9365828352331335, 'bagging_freq': 5, 'min_child_samples': 44}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,588] Trial 36 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 1.3028552065298295e-06, 'lambda_l2': 0.023171126202414804, 'num_leaves': 95, 'feature_fraction': 0.710371746744967, 'bagging_fraction': 0.8894773253383287, 'bagging_freq': 6, 'min_child_samples': 34}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,635] Trial 37 finished with value: 0.6701030927835051 and parameters: {'lambda_l1': 7.44964879001338e-08, 'lambda_l2': 0.06294887033248978, 'num_leaves': 136, 'feature_fraction': 0.6316390942535879, 'bagging_fraction': 0.9014060546396416, 'bagging_freq': 6, 'min_child_samples': 51}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,686] Trial 38 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 5.325778921197512e-08, 'lambda_l2': 0.20445514971240586, 'num_leaves': 112, 'feature_fraction': 0.5230889734145455, 'bagging_fraction': 0.9816678737190976, 'bagging_freq': 7, 'min_child_samples': 57}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,735] Trial 39 finished with value: 0.6804123711340206 and parameters: {'lambda_l1': 4.7511773834619864e-08, 'lambda_l2': 0.02514380008938536, 'num_leaves': 138, 'feature_fraction': 0.7111539893620578, 'bagging_fraction': 0.8833582862460301, 'bagging_freq': 6, 'min_child_samples': 54}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,774] Trial 40 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 3.0564025795197786e-08, 'lambda_l2': 0.12397258256887672, 'num_leaves': 137, 'feature_fraction': 0.6461424282640047, 'bagging_fraction': 0.5324783811202445, 'bagging_freq': 6, 'min_child_samples': 61}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,825] Trial 41 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 3.3727514014418355e-07, 'lambda_l2': 0.010951692721787278, 'num_leaves': 157, 'feature_fraction': 0.6196906934141999, 'bagging_fraction': 0.8437927827017727, 'bagging_freq': 5, 'min_child_samples': 50}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,874] Trial 42 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 1.2087664072238807e-08, 'lambda_l2': 0.49558834292392473, 'num_leaves': 226, 'feature_fraction': 0.5652654510172788, 'bagging_fraction': 0.9292197841216924, 'bagging_freq': 6, 'min_child_samples': 76}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,920] Trial 43 finished with value: 0.5773195876288659 and parameters: {'lambda_l1': 1.488523021341524e-07, 'lambda_l2': 0.0009503296420209413, 'num_leaves': 74, 'feature_fraction': 0.7030031109017986, 'bagging_fraction': 0.796062159574006, 'bagging_freq': 7, 'min_child_samples': 71}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:57,967] Trial 44 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 6.013230495749735e-08, 'lambda_l2': 0.08148369049962634, 'num_leaves': 136, 'feature_fraction': 0.6734960071279406, 'bagging_fraction': 0.8919550070269384, 'bagging_freq': 6, 'min_child_samples': 68}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,006] Trial 45 finished with value: 0.6597938144329897 and parameters: {'lambda_l1': 5.3732311601291164e-08, 'lambda_l2': 0.08558852871462508, 'num_leaves': 145, 'feature_fraction': 0.6710429820794592, 'bagging_fraction': 0.9051621339543836, 'bagging_freq': 6, 'min_child_samples': 91}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,049] Trial 46 finished with value: 0.6494845360824743 and parameters: {'lambda_l1': 1.0376029074704222e-08, 'lambda_l2': 0.503619367145951, 'num_leaves': 184, 'feature_fraction': 0.7840994794550504, 'bagging_fraction': 0.9619079256864517, 'bagging_freq': 7, 'min_child_samples': 85}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,090] Trial 47 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 4.2238560171683716e-08, 'lambda_l2': 0.002987644916951665, 'num_leaves': 169, 'feature_fraction': 0.6718888831746634, 'bagging_fraction': 0.9125809175142058, 'bagging_freq': 5, 'min_child_samples': 93}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,131] Trial 48 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 8.624139664891862e-07, 'lambda_l2': 0.03134613254748193, 'num_leaves': 130, 'feature_fraction': 0.5952808600927564, 'bagging_fraction': 0.9845271178059675, 'bagging_freq': 6, 'min_child_samples': 82}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,176] Trial 49 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 2.907860178202847e-07, 'lambda_l2': 0.00802628713432776, 'num_leaves': 142, 'feature_fraction': 0.5951324352846703, 'bagging_fraction': 0.8347116028076522, 'bagging_freq': 5, 'min_child_samples': 56}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,222] Trial 50 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 8.889104300878287e-08, 'lambda_l2': 4.859318003109942, 'num_leaves': 46, 'feature_fraction': 0.7222683194080773, 'bagging_fraction': 0.877642654441204, 'bagging_freq': 7, 'min_child_samples': 49}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,266] Trial 51 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 1.0774538890830019e-08, 'lambda_l2': 0.6322465999477374, 'num_leaves': 186, 'feature_fraction': 0.7927797479849753, 'bagging_fraction': 0.9635674493686694, 'bagging_freq': 7, 'min_child_samples': 90}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,309] Trial 52 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 2.2918883926181454e-08, 'lambda_l2': 0.9446363444362155, 'num_leaves': 180, 'feature_fraction': 0.7869258622976768, 'bagging_fraction': 0.9413959824577917, 'bagging_freq': 7, 'min_child_samples': 83}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,352] Trial 53 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 2.3066985382308045e-07, 'lambda_l2': 2.7909003564564623, 'num_leaves': 223, 'feature_fraction': 0.831558758453512, 'bagging_fraction': 0.9212973894041482, 'bagging_freq': 6, 'min_child_samples': 83}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,391] Trial 54 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 9.02645613878104, 'lambda_l2': 0.21455423042697092, 'num_leaves': 146, 'feature_fraction': 0.7673220579579634, 'bagging_fraction': 0.9725054934837778, 'bagging_freq': 5, 'min_child_samples': 88}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,433] Trial 55 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 3.735548167098131e-06, 'lambda_l2': 0.061787491764927156, 'num_leaves': 12, 'feature_fraction': 0.8658399848573152, 'bagging_fraction': 0.9929160481707565, 'bagging_freq': 6, 'min_child_samples': 97}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,482] Trial 56 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 2.44572093114845e-08, 'lambda_l2': 0.01601918337286541, 'num_leaves': 248, 'feature_fraction': 0.6864163930692038, 'bagging_fraction': 0.8689801445498985, 'bagging_freq': 7, 'min_child_samples': 64}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,520] Trial 57 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 7.799063476995455e-08, 'lambda_l2': 0.0013523642383443128, 'num_leaves': 25, 'feature_fraction': 0.822350077173356, 'bagging_fraction': 0.951167383652978, 'bagging_freq': 6, 'min_child_samples': 99}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,565] Trial 58 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 1.0019095004497044e-08, 'lambda_l2': 0.30842271948488525, 'num_leaves': 164, 'feature_fraction': 0.8984664206099265, 'bagging_fraction': 0.9154274954761641, 'bagging_freq': 6, 'min_child_samples': 95}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,611] Trial 59 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 6.940445378204515e-07, 'lambda_l2': 1.7872546444995205, 'num_leaves': 121, 'feature_fraction': 0.7403439474957583, 'bagging_fraction': 0.8891714403716575, 'bagging_freq': 7, 'min_child_samples': 87}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,661] Trial 60 finished with value: 0.5876288659793815 and parameters: {'lambda_l1': 1.4006559346598766e-06, 'lambda_l2': 0.00038237680175852467, 'num_leaves': 180, 'feature_fraction': 0.6570019486070904, 'bagging_fraction': 0.4167762215365646, 'bagging_freq': 5, 'min_child_samples': 28}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,693] Trial 61 finished with value: 0.5567010309278351 and parameters: {'lambda_l1': 5.112975804323173e-06, 'lambda_l2': 0.049199387528184826, 'num_leaves': 2, 'feature_fraction': 0.8577057061248662, 'bagging_fraction': 0.9999995384347473, 'bagging_freq': 6, 'min_child_samples': 97}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,735] Trial 62 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 4.520427172617077e-08, 'lambda_l2': 0.004105948771276782, 'num_leaves': 169, 'feature_fraction': 0.6165924728468839, 'bagging_fraction': 0.9106091776814556, 'bagging_freq': 5, 'min_child_samples': 93}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,781] Trial 63 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 1.0406405698551065e-07, 'lambda_l2': 0.006312701855643564, 'num_leaves': 148, 'feature_fraction': 0.7224505109125556, 'bagging_fraction': 0.9395921506591066, 'bagging_freq': 4, 'min_child_samples': 78}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,827] Trial 64 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 2.1556381714386145e-08, 'lambda_l2': 0.09792410157499155, 'num_leaves': 135, 'feature_fraction': 0.6723587382056917, 'bagging_fraction': 0.8780137767671099, 'bagging_freq': 6, 'min_child_samples': 69}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,888] Trial 65 finished with value: 0.6701030927835051 and parameters: {'lambda_l1': 1.8071208271957912e-07, 'lambda_l2': 0.0034724003889978696, 'num_leaves': 198, 'feature_fraction': 0.6594017623998709, 'bagging_fraction': 0.9104324997563628, 'bagging_freq': 5, 'min_child_samples': 39}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:58,950] Trial 66 finished with value: 0.5876288659793815 and parameters: {'lambda_l1': 1.5665105463909573e-07, 'lambda_l2': 0.020807219922644858, 'num_leaves': 212, 'feature_fraction': 0.7984762047443474, 'bagging_fraction': 0.9748215549353776, 'bagging_freq': 5, 'min_child_samples': 39}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,005] Trial 67 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 4.903347101930109e-07, 'lambda_l2': 0.0019893574758487165, 'num_leaves': 203, 'feature_fraction': 0.6909844457431021, 'bagging_fraction': 0.8280155753148737, 'bagging_freq': 7, 'min_child_samples': 44}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,059] Trial 68 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 2.0513774019282114e-06, 'lambda_l2': 0.0006224123133403558, 'num_leaves': 236, 'feature_fraction': 0.5740784203604137, 'bagging_fraction': 0.952615339727124, 'bagging_freq': 4, 'min_child_samples': 54}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,109] Trial 69 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 1.9421353391834478e-07, 'lambda_l2': 3.0795336416012803e-05, 'num_leaves': 188, 'feature_fraction': 0.6580612264209443, 'bagging_fraction': 0.9024202512875547, 'bagging_freq': 6, 'min_child_samples': 60}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,303] Trial 70 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 0.010102843171683626, 'lambda_l2': 0.00011559581913957425, 'num_leaves': 114, 'feature_fraction': 0.9248195512866197, 'bagging_fraction': 0.9358181911369988, 'bagging_freq': 5, 'min_child_samples': 8}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,357] Trial 71 finished with value: 0.6701030927835051 and parameters: {'lambda_l1': 2.401096840663766e-07, 'lambda_l2': 8.758926788881231e-06, 'num_leaves': 191, 'feature_fraction': 0.6528809407039962, 'bagging_fraction': 0.9094609530414279, 'bagging_freq': 6, 'min_child_samples': 60}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,408] Trial 72 finished with value: 0.6494845360824743 and parameters: {'lambda_l1': 6.735591028253895e-08, 'lambda_l2': 4.860856034871601e-06, 'num_leaves': 200, 'feature_fraction': 0.6282002821966063, 'bagging_fraction': 0.8696802596949178, 'bagging_freq': 6, 'min_child_samples': 51}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,467] Trial 73 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 1.673066054158701e-05, 'lambda_l2': 1.310847641882981e-05, 'num_leaves': 208, 'feature_fraction': 0.5436511114417195, 'bagging_fraction': 0.9243043684644678, 'bagging_freq': 6, 'min_child_samples': 45}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,520] Trial 74 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 3.6884394439149844e-07, 'lambda_l2': 6.338332464375993e-07, 'num_leaves': 193, 'feature_fraction': 0.629120733750966, 'bagging_fraction': 0.8653321994372802, 'bagging_freq': 6, 'min_child_samples': 53}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,582] Trial 75 finished with value: 0.6082474226804123 and parameters: {'lambda_l1': 3.49453884241575e-08, 'lambda_l2': 0.01210678539674281, 'num_leaves': 222, 'feature_fraction': 0.8784670344396701, 'bagging_fraction': 0.8922396128161353, 'bagging_freq': 1, 'min_child_samples': 40}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,635] Trial 76 finished with value: 0.6597938144329897 and parameters: {'lambda_l1': 1.6842792918949188e-08, 'lambda_l2': 0.00019653849031981183, 'num_leaves': 178, 'feature_fraction': 0.7755588267402446, 'bagging_fraction': 0.843351228692369, 'bagging_freq': 5, 'min_child_samples': 47}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,696] Trial 77 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 1.01680570200375e-06, 'lambda_l2': 0.00024027165819894903, 'num_leaves': 175, 'feature_fraction': 0.7536666478160248, 'bagging_fraction': 0.8032698698991847, 'bagging_freq': 5, 'min_child_samples': 36}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,751] Trial 78 finished with value: 0.6494845360824743 and parameters: {'lambda_l1': 1.816017148229986e-08, 'lambda_l2': 6.1474361753054505e-06, 'num_leaves': 125, 'feature_fraction': 0.7046190004139418, 'bagging_fraction': 0.856269181184023, 'bagging_freq': 4, 'min_child_samples': 48}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,807] Trial 79 finished with value: 0.6494845360824743 and parameters: {'lambda_l1': 1.200719856196257e-07, 'lambda_l2': 6.664342488735237e-05, 'num_leaves': 153, 'feature_fraction': 0.8392894032408839, 'bagging_fraction': 0.8400450875674357, 'bagging_freq': 5, 'min_child_samples': 59}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,862] Trial 80 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 0.00048177140752903946, 'lambda_l2': 0.001373911023051708, 'num_leaves': 88, 'feature_fraction': 0.6453741952613149, 'bagging_fraction': 0.7714481057415703, 'bagging_freq': 5, 'min_child_samples': 42}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,909] Trial 81 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 1.0735993209699089e-07, 'lambda_l2': 3.576946094979641e-05, 'num_leaves': 161, 'feature_fraction': 0.8392579561263869, 'bagging_fraction': 0.8428637665430994, 'bagging_freq': 5, 'min_child_samples': 60}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:52:59,959] Trial 82 finished with value: 0.5773195876288659 and parameters: {'lambda_l1': 1.6116191521589e-08, 'lambda_l2': 0.1750743298328556, 'num_leaves': 214, 'feature_fraction': 0.8068480360072084, 'bagging_fraction': 0.7190867733331979, 'bagging_freq': 6, 'min_child_samples': 47}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,005] Trial 83 finished with value: 0.5979381443298969 and parameters: {'lambda_l1': 3.6244693361840586e-08, 'lambda_l2': 0.0395261089162213, 'num_leaves': 193, 'feature_fraction': 0.6101492617129312, 'bagging_fraction': 0.9040847659320246, 'bagging_freq': 6, 'min_child_samples': 64}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,093] Trial 84 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 0.0360696144211808, 'lambda_l2': 1.676876085589459e-06, 'num_leaves': 178, 'feature_fraction': 0.7688205052285849, 'bagging_fraction': 0.9644117771214478, 'bagging_freq': 7, 'min_child_samples': 25}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,152] Trial 85 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 0.0025317971384975625, 'lambda_l2': 4.245271508459092e-06, 'num_leaves': 128, 'feature_fraction': 0.7107105701727443, 'bagging_fraction': 0.854804609587016, 'bagging_freq': 4, 'min_child_samples': 48}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,208] Trial 86 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 6.491474164915823e-08, 'lambda_l2': 7.894686921238901e-06, 'num_leaves': 199, 'feature_fraction': 0.6606049409912244, 'bagging_fraction': 0.886415933370712, 'bagging_freq': 6, 'min_child_samples': 52}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,254] Trial 87 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 2.698560588587222e-07, 'lambda_l2': 6.595040225717728e-05, 'num_leaves': 154, 'feature_fraction': 0.8430419198187358, 'bagging_fraction': 0.7937125588072164, 'bagging_freq': 5, 'min_child_samples': 59}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,306] Trial 88 finished with value: 0.6701030927835051 and parameters: {'lambda_l1': 6.119409787808501e-07, 'lambda_l2': 1.0081685160505195e-07, 'num_leaves': 141, 'feature_fraction': 0.6334579114648734, 'bagging_fraction': 0.871845162124506, 'bagging_freq': 6, 'min_child_samples': 56}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,361] Trial 89 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 5.637964673150473e-07, 'lambda_l2': 1.05121673456488e-07, 'num_leaves': 107, 'feature_fraction': 0.5838123111096217, 'bagging_fraction': 0.9251839789795582, 'bagging_freq': 6, 'min_child_samples': 56}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,494] Trial 90 finished with value: 0.5876288659793815 and parameters: {'lambda_l1': 1.6806207961381285e-06, 'lambda_l2': 6.467028044506913e-08, 'num_leaves': 144, 'feature_fraction': 0.6057246656792723, 'bagging_fraction': 0.8760633770327991, 'bagging_freq': 6, 'min_child_samples': 10}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,546] Trial 91 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 2.053056716595199e-07, 'lambda_l2': 2.721774883853869e-08, 'num_leaves': 128, 'feature_fraction': 0.699639617134872, 'bagging_fraction': 0.9097114020923097, 'bagging_freq': 4, 'min_child_samples': 54}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,600] Trial 92 finished with value: 0.6288659793814433 and parameters: {'lambda_l1': 5.4765312985088413e-08, 'lambda_l2': 1.8143731960036184e-05, 'num_leaves': 164, 'feature_fraction': 0.6533879011958812, 'bagging_fraction': 0.8731439954121738, 'bagging_freq': 6, 'min_child_samples': 51}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,702] Trial 93 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 0.00012254855043861777, 'lambda_l2': 3.2943854600265615e-08, 'num_leaves': 205, 'feature_fraction': 0.6357908589035982, 'bagging_fraction': 0.9374493575059331, 'bagging_freq': 6, 'min_child_samples': 15}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,752] Trial 94 finished with value: 0.6391752577319587 and parameters: {'lambda_l1': 2.7246828640566017e-08, 'lambda_l2': 0.40769287360746614, 'num_leaves': 185, 'feature_fraction': 0.7821721339517425, 'bagging_fraction': 0.9473080706472421, 'bagging_freq': 7, 'min_child_samples': 67}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,799] Trial 95 finished with value: 0.6701030927835051 and parameters: {'lambda_l1': 2.7904187524246725e-06, 'lambda_l2': 0.00018605486253757606, 'num_leaves': 150, 'feature_fraction': 0.8185360993568481, 'bagging_fraction': 0.8226219294221964, 'bagging_freq': 5, 'min_child_samples': 62}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,845] Trial 96 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 3.2940984814061797e-06, 'lambda_l2': 0.00020739478435185973, 'num_leaves': 140, 'feature_fraction': 0.8249309602931585, 'bagging_fraction': 0.8987506090473417, 'bagging_freq': 5, 'min_child_samples': 62}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,892] Trial 97 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 2.574907775677031e-05, 'lambda_l2': 0.0005391091608451983, 'num_leaves': 132, 'feature_fraction': 0.8775332119531765, 'bagging_fraction': 0.8324420968792035, 'bagging_freq': 5, 'min_child_samples': 57}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:00,975] Trial 98 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 5.560840152978736e-06, 'lambda_l2': 0.00012951037155511965, 'num_leaves': 150, 'feature_fraction': 0.8142168032900962, 'bagging_fraction': 0.8092171311024354, 'bagging_freq': 6, 'min_child_samples': 19}. Best is trial 4 with value: 0.6907216494845361.
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\lightgbm\basic.py:179: UserWarning: Converting column-vector to 1d array
#   _log_warning('Converting column-vector to 1d array')
# [I 2021-11-22 14:53:01,040] Trial 99 finished with value: 0.6185567010309279 and parameters: {'lambda_l1': 2.572712509288742e-06, 'lambda_l2': 3.052208767154974e-07, 'num_leaves': 64, 'feature_fraction': 0.6813991085304447, 'bagging_fraction': 0.9207852490136019, 'bagging_freq': 5, 'min_child_samples': 31}. Best is trial 4 with value: 0.6907216494845361.

# %%
print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Number of finished trials: 100
# Best trial:
#   Value: 0.6907216494845361
#   Params:
#     lambda_l1: 1.7223208762016493e-06
#     lambda_l2: 0.0003938813884026949
#     num_leaves: 23
#     feature_fraction: 0.8164434077638283
#     bagging_fraction: 0.9379967492292598
#     bagging_freq: 6
#     min_child_samples: 9

# %%
import json

with open('lgbm_params.json', 'w') as fp:
    json.dump(trial.params, fp)
